# %% [markdown]
# ## T Test

# %% [markdown]
# A t-test is a type of inferential statistic which is used to determine if there is a significant difference between the means of two groups which may be related in certain features
#
# T-test has 2 types : 1. one sampled t-test 2. two-sampled t-test.

# %% [markdown]
# ## One-sample T-test with Python

# %% [markdown]
# ![t_test.png](attachment:t_test.png)

# %%
ages=[10,20,35,50,28,40,55,18,16,55,30,25,43,18,30,28,14,24,16,17,32,35,26,27,65,18,43,23,21,20,19,70]

# %%
len(ages)
# Out:
# 32

# %%
import numpy as np
ages_mean = np.mean(ages)
print(ages_mean)
# Out:
# 30.34375

# %%
sample_size = 10
age_sample = np.random.choice(ages,sample_size)

# %%
age_sample
# Out:
# array([65, 43, 19, 40, 25, 55, 20, 70, 50, 32])

# %%
from scipy.stats import ttest_1samp

# %%
ttest,p_value=ttest_1samp(age_sample,30)

# %%
print(p_value)
# Out:
# 0.06753681311586267

# %%
if p_value < 0.05:    # alpha value is 0.05 or 5%
    print(" we are rejecting null hypothesis")
else:
    print("we are accepting null hypothesis")
    
    ## here p value is bigger than 0.05 so accept
# Out:
# we are accepting null hypothesis

# %%
## Ex - 2

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import math
np.random.seed(6)
school_ages=stats.poisson.rvs(loc=18,mu=35,size=1500)
classA_ages=stats.poisson.rvs(loc=18,mu=30,size=60)
# from 1500 data taking only 60
## graph satarting 18 loc
### mean is 30

# %%
classA_ages.mean()
# school_ages = population mena
# calssA_ages = sample mean
# Out:
# 46.9

# %%
p_value=stats.ttest_1samp(a=classA_ages,popmean=school_ages.mean())

# %%
p_value
# Out:
# TtestResult(statistic=-9.604796510704091, pvalue=1.139027071016194e-13, df=59)

# %%
_,p_value=stats.ttest_1samp(a=classA_ages,popmean=school_ages.mean())

# %%
p_value
# Out:
# 1.139027071016194e-13

# %%
school_ages.mean()
# Out:
# 53.303333333333335

# %%
if p_value < 0.05:    # alpha value is 0.05 or 5%
    print(" we are rejecting null hypothesis")
else:
    print("we are accepting null hypothesis")
# Out:
#  we are rejecting null hypothesis

# %% [markdown]
# ## Two-sample T-test With Python

# %% [markdown]
# ![Two_sample_ttest.png](attachment:Two_sample_ttest.png)

# %%
# ttest_ind - will use it

# %%
np.random.seed(12)
ClassB_ages=stats.poisson.rvs(loc=18,mu=33,size=60)
ClassB_ages.mean()
# Out:
# 50.63333333333333

# %%
_,p_value=stats.ttest_ind(a=classA_ages,b=ClassB_ages,equal_var=False)
     # here a is one feature and b is another

# %%
p_value
# Out:
# 0.00039942095100859375

# %%
if p_value < 0.05:    # alpha value is 0.05 or 5%
    print(" we are rejecting null hypothesis")
else:
    print("we are accepting null hypothesis")
# Out:
#  we are rejecting null hypothesis

# %% [markdown]
# ## Paired T-test With Python

# %%
#Paired T-test With Python
#When you want to check how different samples from the 
#same group are, you can go for a paired T-test

# %%
## here ttest_rel - wiil be used

# %%
weight1=[25,30,28,35,28,34,26,29,30,26,28,32,31,30,45]
weight2=weight1+stats.norm.rvs(scale=5,loc=-1.25,size=15)

# %%
print(weight1)
print(weight2)
# Out:
# [25, 30, 28, 35, 28, 34, 26, 29, 30, 26, 28, 32, 31, 30, 45]
# [30.57926457 34.91022437 29.00444617 30.54295091 19.86201983 37.57873174
#  18.3299827  21.3771395  36.36420881 32.05941216 26.93827982 29.519014
#  26.42851213 30.50667769 41.32984284]

# %%
weight_df=pd.DataFrame({"weight_10":np.array(weight1),
                         "weight_20":np.array(weight2),
                       "weight_change":np.array(weight2)-np.array(weight1)})

# %%
weight_df
# Out:
#     weight_10  weight_20  weight_change
# 0          25  30.579265       5.579265
# 1          30  34.910224       4.910224
# 2          28  29.004446       1.004446
# 3          35  30.542951      -4.457049
# 4          28  19.862020      -8.137980
# 5          34  37.578732       3.578732
# 6          26  18.329983      -7.670017
# 7          29  21.377139      -7.622861
# 8          30  36.364209       6.364209
# 9          26  32.059412       6.059412
# 10         28  26.938280      -1.061720
# 11         32  29.519014      -2.480986
# 12         31  26.428512      -4.571488
# 13         30  30.506678       0.506678
# 14         45  41.329843      -3.670157

# %%
_,p_value=stats.ttest_rel(a=weight1,b=weight2)
# Calculate the t-test on TWO RELATED samples of 
# scores, a and b.

# %%
print(p_value)
# Out:
# 0.5732936534411279

# %%
if p_value < 0.05:    # alpha value is 0.05 or 5%
    print(" we are rejecting null hypothesis")
else:
    print("we are accepting null hypothesis")
# Out:
# we are accepting null hypothesis

# %% [markdown]
# ## Correlation

# %%
import seaborn as sns
df=sns.load_dataset('iris')

# %%
df.shape
# Out:
# (150, 5)

# %%
df.corr()
# Out:
# C:\Users\Sudip_21053329\AppData\Local\Temp\ipykernel_18852\3683255628.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.pairplot(df)
